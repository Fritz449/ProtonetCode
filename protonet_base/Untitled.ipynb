# %%
import numpy as np
import matplotlib.pyplot as plt

losses_train_basic = np.load('losses_train_basic.npy')
losses_basic = np.load('losses_basic.npy')
f1_train_basic = np.load('f1_train_basic.npy')
f1_basic = np.load('f1_basic.npy')

losses_train_1st = np.load('losses_train_1st.npy')
losses_1st  = np.load('losses_1st.npy')
f1_train_1st  = np.load('f1_train_1st.npy')
f1_1st  = np.load('f1_1st.npy')

losses_train_2st = np.load('losses_train_2st.npy')
losses_2st  = np.load('losses_2st.npy')
f1_train_2st  = np.load('f1_train_2st.npy')
f1_2st  = np.load('f1_2st.npy')

losses_train_3st = np.load('losses_train_3st.npy')
losses_3st  = np.load('losses_3st.npy')
f1_train_3st  = np.load('f1_train_3st.npy')
f1_3st  = np.load('f1_3st.npy')

losses_train_4st = np.load('losses_train_4st.npy')
losses_4st  = np.load('losses_4st.npy')
f1_train_4st  = np.load('f1_train_4st.npy')
f1_4st  = np.load('f1_4st.npy')

losses_train_5st = np.load('losses_train_5st.npy')
losses_5st  = np.load('losses_5st.npy')
f1_train_5st  = np.load('f1_train_5st.npy')
f1_5st  = np.load('f1_5st.npy')

plt.figure()
plt.plot(losses_train_basic)
plt.plot(losses_train_1st)
plt.plot(losses_train_2st)
plt.plot(losses_train_3st)
plt.plot(losses_train_4st)
plt.plot(losses_train_5st)


plt.figure()
plt.plot(losses_basic)
plt.plot(losses_1st)
plt.plot(losses_2st)
plt.plot(losses_3st)
plt.plot(losses_4st)
plt.plot(losses_5st)



plt.figure()
plt.plot(f1_train_basic)
plt.plot(f1_train_1st)
plt.plot(f1_train_2st)
plt.plot(f1_train_3st)
plt.plot(f1_train_4st)
plt.plot(f1_train_5st)

plt.figure()
plt.plot(f1_basic)
plt.plot(f1_1st)
plt.plot(f1_2st)
plt.plot(f1_3st)
plt.plot(f1_4st)
plt.plot(f1_5st)



plt.show()
